# %%
from nba_api.stats.static import teams
nba_teams = teams.get_teams()

magic = [team for team in nba_teams if team['abbreviation'] == 'ORL'][0]
magic_id = magic['id']
print(f'magic id: {magic_id}')
# Out:
# magic id: 1610612753

# %%
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=magic_id,
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']

# %%
'''
for game in games:
    dfs.append(playbyplayv2.PlayByPlayV2(game['GAME_ID']).get_data_frames()[0])
    time.sleep(2)
'''
# Out:
# "\nfor game in games:\n    dfs.append(playbyplayv2.PlayByPlayV2(game['GAME_ID']).get_data_frames()[0])\n    time.sleep(2)\n"

# %%
dfs = []
from nba_api.stats.endpoints import playbyplayv2
import time
for game in games:
    dfs.append(playbyplayv2.PlayByPlayV2(game_id = game['GAME_ID']).get_data_frames()[0])
    time.sleep(3) # avoid hitting rate limit
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 5
#       3 import time
#       4 for game in games:
# ----> 5     dfs.append(playbyplayv2.PlayByPlayV2(game_id = game['GAME_ID']).get_data_frames()[0])
#       6     time.sleep(3) # avoid hitting rate limit
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nba_api\stats\endpoints\playbyplayv2.py:74, in PlayByPlayV2.__init__(self, game_id, end_period, start_period, proxy, headers, timeout, get_request)
#      68 self.parameters = {
#      69     "GameID": game_id,
#      70     "EndPeriod": end_period,
#      71     "StartPeriod": start_period,
#      72 }
#      73 if get_request:
# ---> 74     self.get_request()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nba_api\stats\endpoints\playbyplayv2.py:84, in PlayByPlayV2.get_request(self)
#      76 def get_request(self):
# ...

# %%
# Out:
# [   ASSISTS
#  0      856]
